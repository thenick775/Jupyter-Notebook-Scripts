# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_fwf(r'2014_CELIAS_Proton_Monitor_5min.txt',index_col=0,header=25,widths=[22,9,9,7,6,10,7,7,7,7,7,8,8])

# %%
fnamedict={0:"_speed.txt",1:"_np.txt",2:"_vth.txt",3:"_ns.txt",4:"_vhe.txt"}

# %%
df.columns
# Out:
# Index(['Unnamed: 1', 'CELIAS/', 'MTOF/PM', 'DATA', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'SOHO OR', 'BIT DAT', 'A', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
df.head(50)
# Out:
#                        Unnamed: 1 CELIAS/ MTOF/PM   DATA Unnamed: 5  \
# InSitu_Start__Time         [km/s]  [cm-3]  [km/s]  [deg]     [km/s]
# YY MON DY DOY:HH:MM:SS      SPEED      Np     Vth    N/S       V_He
# 14 Jan 01 001:00:00:10        385    3.71      26   -2.7        391
# 14 Jan 01 001:00:05:12        380    4.20      25   -2.3        385
# 14 Jan 01 001:00:10:15        373    5.01      24   -2.3        378
# 14 Jan 01 001:00:15:17        386    4.77      25   -2.8        391
# 14 Jan 01 001:00:20:18        384    6.24      25   -4.5        389
# 14 Jan 01 001:00:25:20        381    5.38      25   -3.5        386
# 14 Jan 01 001:00:30:24        382    4.37      25   -2.7        387
# 14 Jan 01 001:00:35:25        383    4.49      25   -2.9        388
# 14 Jan 01 001:00:40:29        395    4.06      27   -3.3        402
# 14 Jan 01 001:00:45:30        385    4.76      26   -2.9        391
# 14 Jan 01 001:00:50:32        370    5.04      23   -1.8        374
# ...

# %%
for x in range(0,5):
    df1=df.iloc[:,[x,5,6,7,8,9,10,11]]
    print(df1)
    df1.to_csv('2014_CELIAS_Proton_Monitor_5min'+fnamedict[x], sep=' ')
# Out:
#                        Unnamed: 1 Unnamed: 6 Unnamed: 7 SOHO OR BIT DAT  \
# InSitu_Start__Time         [km/s]       [Re]       [Re]    [Re]   [Mkm]
# YY MON DY DOY:HH:MM:SS      SPEED      GSE_X      GSE_Y   GSE_Z   RANGE
# 14 Jan 01 001:00:00:10        385      256.5      -29.0   -18.5   145.5
# 14 Jan 01 001:00:05:12        380      256.5      -29.1   -18.5   145.5
# 14 Jan 01 001:00:10:15        373      256.5      -29.1   -18.5   145.5
# 14 Jan 01 001:00:15:17        386      256.5      -29.1   -18.5   145.5
# 14 Jan 01 001:00:20:18        384      256.5      -29.1   -18.5   145.5
# 14 Jan 01 001:00:25:20        381      256.5      -29.1   -18.5   145.5
# 14 Jan 01 001:00:30:24        382      256.5      -29.1   -18.5   145.5
# 14 Jan 01 001:00:35:25        383      256.5      -29.1   -18.5   145.5
# 14 Jan 01 001:00:40:29        395      256.5      -29.1   -18.5   145.5
# 14 Jan 01 001:00:45:30        385      256.5      -29.2   -18.5   145.5
# ...
