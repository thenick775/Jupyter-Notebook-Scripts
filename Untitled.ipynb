# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('Multi-GAS data.csv', index_col=0, low_memory=False)

# %%
df.columns
# Out:
# Index(['Time', 'Status flag', 'Instrument temperature',
#        'Air relative humidity', 'Air pressure', 'Sample pressure',
#        'Mean horizontal wind speed', 'Mean horizontal wind direction',
#        'H2O mixing ratio', 'CO2 mixing ratio', 'SO2 mixing ratio',
#        'H2S mixing ratio'],
#       dtype='object')

# %%
dfnew=df.iloc[:,[0,2]]

# %%
dfnew
# Out:
#              Time Instrument temperature
# Date
# NaN           UTC        degrees Celsius
# 5/14/16  17:45:00                     20
# 5/14/16  17:45:02                  19.97
# 5/14/16  17:45:04                  19.97
# 5/14/16  17:45:06                  19.97
# 5/14/16  17:45:08                  19.97
# 5/14/16  17:45:10                     20
# 5/14/16  17:45:12                     20
# 5/14/16  17:45:14                     20
# 5/14/16  17:45:16                  19.97
# 5/14/16  17:45:18                  19.97
# 5/14/16  17:45:20                  19.97
# 5/14/16  17:45:22                     20
# 5/14/16  17:45:24                  19.97
# 5/14/16  17:45:26                  19.97
# 5/14/16  17:45:28                  19.97
# 5/14/16  17:45:30                  19.97
# 5/14/16  17:45:32                  19.97
# 5/14/16  17:45:34                  19.97
# 5/14/16  17:45:36                  19.97
# 5/14/16  17:45:38                  19.97
# 5/14/16  17:45:40                  19.97
# ...

# %%
dfnew.to_csv('Multi-GAS_instemp_data.csv')
