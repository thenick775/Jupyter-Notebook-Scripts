# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_fwf(r'ct4-9908-04_ODV.txt',index_col=2,sep='	',header=None)

# %%
df=pd.read_csv('ct4-9908-04_ODV.txt', sep='	',skiprows=1)

# %%
df=pd.read_csv('ct4-9908-04_ODV.txt', skiprows=0, 
                     sep='\t', engine='python')

# %%
df
# Out:
#                                                                                                                                                 // created: 08-Apr-2018 09:14:31
# Cruise      Station Type mon/day/yr hh:mm Longitude [degrees_east] Latitude [degrees_north] Depth [m] QF Temperature [�C] QF Salinity [psu] QF
# ct4-9908-04 1       C    06/11/2004 08:42 -122.899                 37.203                   5.0       0  11.8270          0  33.2968        0                                NaN
#                                                                                             6.0       0  11.7647          0  33.3088        0                                NaN
#                                                                                             7.0       0  11.7024          0  33.3208        0                                NaN
# ...

# %%
df.head(10)
# Out:
#                                                                                                                                                 // created: 08-Apr-2018 09:14:31
# Cruise      Station Type mon/day/yr hh:mm Longitude [degrees_east] Latitude [degrees_north] Depth [m] QF Temperature [�C] QF Salinity [psu] QF
# ct4-9908-04 1       C    06/11/2004 08:42 -122.899                 37.203                   5.0       0  11.8270          0  33.2968        0                                NaN
#                                                                                             6.0       0  11.7647          0  33.3088        0                                NaN
#                                                                                             7.0       0  11.7024          0  33.3208        0                                NaN
# ...

# %%
df.to_csv('tester_2014.txt')
