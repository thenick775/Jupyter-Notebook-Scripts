# %%
import numpy as np

# %%
import pandas as pd

# %%
df= pd.read_csv('edu_ucdavis_bml_hog_island_oyster_084d_868d_4856.csv')

# %%
df.columns
# Out:
# Index(['time (UTC)', 'latitude (degrees_north)', 'longitude (degrees_east)',
#        'station', 'sea_water_ph_reported_on_total_scale (1)'],
#       dtype='object')

# %%
df.isnull().values.ravel().sum()
# Out:
# 207

# %%
df.isnull().sum(axis = 0)
# Out:
# time (UTC)                                    0
# latitude (degrees_north)                      0
# longitude (degrees_east)                      0
# station                                       0
# sea_water_ph_reported_on_total_scale (1)    207
# dtype: int64

# %%
df.count()
# Out:
# time (UTC)                                  13951
# latitude (degrees_north)                    13951
# longitude (degrees_east)                    13951
# station                                     13951
# sea_water_ph_reported_on_total_scale (1)    13744
# dtype: int64

# %%
df.head(25)
# Out:
#               time (UTC)  latitude (degrees_north)  longitude (degrees_east)  \
# 0   2014-05-31T17:59:11Z                    38.162                 -122.8939
# 1   2014-05-31T18:14:22Z                    38.162                 -122.8939
# 2   2014-05-31T18:29:37Z                    38.162                 -122.8939
# 3   2014-05-31T18:44:51Z                    38.162                 -122.8939
# 4   2014-05-31T19:00:06Z                    38.162                 -122.8939
# 5   2014-05-31T19:15:21Z                    38.162                 -122.8939
# 6   2014-05-31T19:30:36Z                    38.162                 -122.8939
# 7   2014-05-31T19:45:51Z                    38.162                 -122.8939
# 8   2014-05-31T20:01:06Z                    38.162                 -122.8939
# 9   2014-05-31T20:16:21Z                    38.162                 -122.8939
# 10  2014-05-31T20:31:36Z                    38.162                 -122.8939
# ...

# %%
df.tail(25)
# Out:
#                  time (UTC)  latitude (degrees_north)  \
# 13926  2014-12-31T17:48:19Z                    38.162
# 13927  2014-12-31T18:03:34Z                    38.162
# 13928  2014-12-31T18:18:48Z                    38.162
# 13929  2014-12-31T18:34:03Z                    38.162
# 13930  2014-12-31T18:49:18Z                    38.162
# 13931  2014-12-31T19:04:33Z                    38.162
# 13932  2014-12-31T19:19:48Z                    38.162
# 13933  2014-12-31T19:35:03Z                    38.162
# 13934  2014-12-31T19:50:18Z                    38.162
# 13935  2014-12-31T20:05:33Z                    38.162
# 13936  2014-12-31T20:20:48Z                    38.162
# 13937  2014-12-31T20:36:03Z                    38.162
# 13938  2014-12-31T20:51:18Z                    38.162
# 13939  2014-12-31T21:06:33Z                    38.162
# 13940  2014-12-31T21:21:48Z                    38.162
# 13941  2014-12-31T21:37:03Z                    38.162
# ...
