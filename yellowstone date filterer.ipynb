# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('YellowstoneSC.csv',index_col=0,parse_dates=True, low_memory=False)

# %%
df.columns
# Out:
# Index(['Specific Conductance (microSiemens/cm)', 'Temperature (degree Celsius)'], dtype='object')

# %%
dfnew=df.loc['2014-01-01':"2014-12-31"]

# %%
dfnew.head(50)
# Out:
#                      Specific Conductance (microSiemens/cm)  \
# Date and Time (MDT)
# 2014-01-01 00:00:00                                     320
# 2014-01-01 00:15:00                                     320
# 2014-01-01 00:30:00                                     320
# 2014-01-01 00:45:00                                     320
# 2014-01-01 01:00:00                                     320
# 2014-01-01 01:15:00                                     320
# 2014-01-01 01:30:00                                     320
# 2014-01-01 01:45:00                                     320
# 2014-01-01 02:00:00                                     320
# 2014-01-01 02:15:00                                     320
# 2014-01-01 02:30:00                                     320
# 2014-01-01 02:45:00                                     321
# 2014-01-01 03:00:00                                     321
# 2014-01-01 03:15:00                                     321
# ...

# %%
dfnew.tail(50)
# Out:
#                      Specific Conductance (microSiemens/cm)  \
# Date and Time (MDT)
# 2014-12-31 11:30:00                                     400
# 2014-12-31 11:45:00                                     400
# 2014-12-31 12:00:00                                     400
# 2014-12-31 12:15:00                                     400
# 2014-12-31 12:30:00                                     399
# 2014-12-31 12:45:00                                     399
# 2014-12-31 13:00:00                                     399
# 2014-12-31 13:15:00                                     399
# 2014-12-31 13:30:00                                     399
# 2014-12-31 13:45:00                                     399
# 2014-12-31 14:00:00                                     398
# 2014-12-31 14:15:00                                     399
# 2014-12-31 14:30:00                                     399
# 2014-12-31 14:45:00                                     399
# ...

# %%
dfnew.count()
# Out:
# Specific Conductance (microSiemens/cm)    35040
# Temperature (degree Celsius)              35040
# dtype: int64

# %%
dfnew.to_csv('YellowstoneSC_2014.csv')
