# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('Annual winter elk movements in the Greater Yellowstone Ecosystem 2001-2015.csv',index_col=1,parse_dates=True, low_memory=False)

# %%
df.columns
# Out:
# Index(['id', 'x.start', 'y.start', 't.end', 'x.end', 'y.end', 'dist'], dtype='object')

# %%
df.head(10)
# Out:
#                    id     x.start    y.start        t.end       x.end  \
# t.start
# 2007-01-01   Abs_UW_1 -109.532055  44.726287  2008.017009 -109.513769
# 2008-01-01   Abs_UW_1 -109.513769  44.759436  2009.008790 -109.483908
# 2009-01-01   Abs_UW_1 -109.483908  44.766559  2010.014269 -109.548219
# 2007-01-01  Abs_UW_10 -109.589423  44.778196  2008.017009 -109.577560
# 2008-01-01  Abs_UW_10 -109.577560  44.751661  2009.011530 -110.126191
# 2009-01-01  Abs_UW_10 -110.126191  44.861649  2010.014269 -109.615563
# 2007-01-01  Abs_UW_11 -109.613441  44.751412  2008.006050 -109.645637
# 2008-01-01  Abs_UW_11 -109.645637  44.818713  2009.047146 -109.553406
# 2007-01-01  Abs_UW_12 -109.111767  44.657892  2008.000571 -109.223135
# 2008-01-01  Abs_UW_12 -109.223135  44.597637  2009.071804 -109.188380
#
#                 y.end       dist
# t.start
# 2007-01-01  44.759436   3.963377
# 2008-01-01  44.766559   2.489929
# 2009-01-01  44.759945   5.136381
# 2007-01-01  44.751661   3.099199
# ...

# %%
dfnew=df.loc['2013-01-01':'2013-12-31']

# %%
dfnew.head(50)
# Out:
#                                            id     x.start    y.start  \
# t.start
# 2013-01-01                       BFH_WYGF_610 -110.312157  42.346708
# 2013-01-01                       BFH_WYGF_612 -110.449298  42.503302
# 2013-01-01                       BFH_WYGF_615 -110.452530  42.516927
# 2013-01-01                       BFH_WYGF_619 -110.307591  42.344790
# 2013-01-01                       BFH_WYGF_620 -110.319878  42.333600
# 2013-01-01                       BFH_WYGF_624 -110.432281  42.489439
# 2013-01-01                       BFH_WYGF_629 -110.421366  42.485787
# 2013-01-01                       BFH_WYGF_630 -110.333009  42.296464
# 2013-01-01                       BFH_WYGF_631 -110.310829  42.467674
# 2013-01-01                       BFH_WYGF_632 -110.306424  42.466719
# 2013-01-01                       BFH_WYGF_634 -110.310596  42.340590
# 2013-01-01                       BFH_WYGF_635 -110.383763  42.460561
# ...

# %%
dfnew.tail(50)
# Out:
#                                            id     x.start    y.start  \
# t.start
# 2013-01-01  MTFWP_130950_West Fork Bitterroot -114.301691  45.533410
# 2013-01-01  MTFWP_131040_West Fork Bitterroot -114.320087  45.662718
# 2013-01-01         MTFWP_131050_South Pioneer -112.957929  45.181136
# 2013-01-01  MTFWP_131139_West Fork Bitterroot -114.423081  45.710212
# 2013-01-01  MTFWP_131150_West Fork Bitterroot -114.319947  45.662870
# 2013-01-01  MTFWP_131230_East Fork Bitterroot -113.928545  45.910202
# 2013-01-01  MTFWP_131320_East Fork Bitterroot -113.924565  45.819202
# 2013-01-01          MTFWP_131370_West Pioneer -113.302152  45.761875
# 2013-01-01  MTFWP_131440_East Fork Bitterroot -114.066708  46.018980
# 2013-01-01  MTFWP_131460_East Fork Bitterroot -114.032104  45.888567
# 2013-01-01          MTFWP_131480_West Pioneer -113.370271  45.487427
# 2013-01-01  MTFWP_131530_East Fork Bitterroot -114.134156  45.935277
# ...

# %%
dfnew
# Out:
#                                            id     x.start    y.start  \
# t.start
# 2013-01-01                       BFH_WYGF_610 -110.312157  42.346708
# 2013-01-01                       BFH_WYGF_612 -110.449298  42.503302
# 2013-01-01                       BFH_WYGF_615 -110.452530  42.516927
# 2013-01-01                       BFH_WYGF_619 -110.307591  42.344790
# 2013-01-01                       BFH_WYGF_620 -110.319878  42.333600
# 2013-01-01                       BFH_WYGF_624 -110.432281  42.489439
# 2013-01-01                       BFH_WYGF_629 -110.421366  42.485787
# 2013-01-01                       BFH_WYGF_630 -110.333009  42.296464
# 2013-01-01                       BFH_WYGF_631 -110.310829  42.467674
# 2013-01-01                       BFH_WYGF_632 -110.306424  42.466719
# 2013-01-01                       BFH_WYGF_634 -110.310596  42.340590
# 2013-01-01                       BFH_WYGF_635 -110.383763  42.460561
# ...

# %%
dfnew.to_csv('ELK_2014.csv')
