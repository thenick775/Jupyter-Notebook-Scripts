# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('Eddy covariance data.csv',index_col=0,low_memory=False)

# %%
df.columns
# Out:
# Index(['Time', 'Sensible heat flux', 'Quality ranking for sensible heat flux',
#        'Latent heat flux', 'Quality ranking for latent heat flux', 'CO2 flux',
#        'Quality ranking for CO2 flux', 'H2O flux',
#        'Quality ranking for H2O flux', 'Friction velocity',
#        'Monin-Obukhov length', 'Wind speed variance in cross-wind direction',
#        'Air temperature', 'Air pressure', 'Mean horizontal wind speed',
#        'Mean horizontal wind direction', 'Rainfall', 'Soil moisture '],
#       dtype='object')

# %%
df.count()

# %%
df.head(50)

# %%
df.tail(50)

# %%
dfnew=df.iloc[:,[0,17]]

# %%
dfnew.head(50)
# Out:
#                     Time  Soil moisture
# Date
# NaN      local time: MDT  volume percent
# 5/14/16            10:00              21
# 5/14/16            10:30              21
# 5/14/16            11:00              21
# 5/14/16            11:30              20
# 5/14/16            12:00              20
# 5/14/16            12:30              20
# 5/14/16            13:00              20
# 5/14/16            13:30              19
# 5/14/16            14:00              19
# 5/14/16            14:30              19
# 5/14/16            15:00              18
# 5/14/16            15:30              18
# 5/14/16            16:00              18
# 5/14/16            16:30              17
# 5/14/16            17:00              17
# 5/14/16            17:30              17
# 5/14/16            18:00              17
# 5/14/16            18:30              17
# 5/14/16            19:00              17
# 5/14/16            19:30              17
# 5/14/16            20:00              17
# ...

# %%
dfnew.tail(50)
# Out:
#           Time Soil moisture
# Date
# 10/2/16   8:00             17
# 10/2/16   8:30             17
# 10/2/16   9:00             17
# 10/2/16   9:30             17
# 10/2/16  10:00             16
# 10/2/16  10:30             18
# 10/2/16  11:00             20
# 10/2/16  11:30             20
# 10/2/16  12:00             20
# 10/2/16  12:30             19
# 10/2/16  13:00             19
# 10/2/16  13:30             18
# 10/2/16  14:00             18
# 10/2/16  14:30             23
# 10/2/16  15:00             25
# 10/2/16  15:30             22
# 10/2/16  16:00             21
# 10/2/16  16:30             20
# 10/2/16  17:00             20
# 10/2/16  17:30             19
# 10/2/16  18:00             24
# 10/2/16  18:30             28
# 10/2/16  19:00             23
# 10/2/16  19:30             22
# 10/2/16  20:00             22
# 10/2/16  20:30             21
# 10/2/16  21:00             21
# 10/2/16  21:30             24
# 10/2/16  22:00             27
# 10/2/16  22:30             24
# ...

# %%
dfnew.to_csv('Eddy covariance data_SM.csv')
